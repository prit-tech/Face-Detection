# %% [markdown]
# <a href="https://colab.research.google.com/github/prit-tech/Face-Detection/blob/master/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center><u>Face Detection</u></center>

# %% [markdown]
# # Objective
# Goal is to predict the boundaries(mask) around the face in a given image.

# %% [markdown]
# ## Dataset
# Faces in images marked with bounding boxes. Have around 500 images with around 1100 faces manually tagged via bounding box.

# %% [markdown]
# ### Mount Google drive if you are using google colab
# - We recommend using Google Colab as you can face memory issues and longer runtimes while running on local

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Change current working directory to project folder

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/Deep Learning')
path = '.'

# %% [markdown]
# ### Load the "images.npy" file
# - This file contains images with details of bounding boxes

# %%
import numpy as np
data = np.load('/content/drive/My Drive/Colab Notebooks/Deep Learning/images.npy', allow_pickle=True)

# %% [markdown]
# * Shape of the data :

# %%
data.shape
# Out:
# (409, 2)

# %% [markdown]
# ### Check one sample from the loaded "images.npy" file

# %%
from matplotlib import pyplot as plt
import IPython.display as display
from PIL import Image, ImageOps

# %%
n = 270
image_det = data[n]
img = image_det[0]
img = Image.fromarray(img, 'RGB')
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Set image dimensions
# - Initialize image height, image width with value: 224

# %%
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224

# %% [markdown]
# ### Create features and labels
# - Here feature is the image
# - The label is the mask
# - Images will be stored in "X_train" array
# - Masks will be stored in "masks" array

# %%
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input

masks = np.zeros((int(data.shape[0]), IMAGE_HEIGHT, IMAGE_WIDTH))
X_train = np.zeros((int(data.shape[0]), IMAGE_HEIGHT, IMAGE_WIDTH, 3))
for index in range(data.shape[0]):
    img = data[index][0]
    img = cv2.resize(img, dsize=(IMAGE_HEIGHT, IMAGE_WIDTH), interpolation=cv2.INTER_CUBIC)
    try:
      img = img[:, :, :3]
    except:
      continue
    X_train[index] = preprocess_input(np.array(img, dtype=np.float32))
    for i in data[index][1]:
        x1 = int(i["points"][0]['x'] * IMAGE_WIDTH)
        x2 = int(i["points"][1]['x'] * IMAGE_WIDTH)
        y1 = int(i["points"][0]['y'] * IMAGE_HEIGHT)
        y2 = int(i["points"][1]['y'] * IMAGE_HEIGHT)
        masks[index][y1:y2, x1:x2] = 1
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
X_train[n]
# Out:
# array([[[ 0.41176474, -0.08235294, -0.49803919],
#         [ 0.41176474, -0.0745098 , -0.51372552],
#         [ 0.4039216 , -0.08235294, -0.52156866],
#         ...,
#         [ 0.38823533, -0.19215685, -0.60784316],
#         [ 0.36470592, -0.20784312, -0.62352943],
#         [ 0.36470592, -0.19999999, -0.6156863 ]],
#
#        [[ 0.42745101, -0.06666666, -0.49803919],
#         [ 0.41960788, -0.06666666, -0.51372552],
#         [ 0.4039216 , -0.08235294, -0.52156866],
#         ...,
#         [ 0.38823533, -0.18431371, -0.6156863 ],
#         [ 0.38039219, -0.18431371, -0.62352943],
#         [ 0.38039219, -0.19215685, -0.6156863 ]],
#
#        [[ 0.42745101, -0.06666666, -0.50588238],
#         [ 0.42745101, -0.06666666, -0.50588238],
#         [ 0.43529415, -0.05882353, -0.50588238],
#         ...,
#         [ 0.41176474, -0.14509803, -0.59215689],
#         [ 0.4039216 , -0.16862744, -0.60784316],
#         [ 0.4039216 , -0.16862744, -0.60000002]],
#
#        ...,
#
#        [[ 0.30196083,  0.03529418, -0.12156862],
#         [ 0.27058828, -0.02745098, -0.18431371],
#         [-0.01176471, -0.23137254, -0.35686272],
#         ...,
#         [ 0.06666672,  0.11372554, -0.19215685],
#         [ 0.05882359,  0.10588241, -0.21568626],
#         [ 0.082353  ,  0.11372554, -0.20784312]],
#
#        [[ 0.30196083, -0.01960784, -0.19999999],
#         [ 0.27058828, -0.04313725, -0.19999999],
#         [ 0.05882359, -0.16862744, -0.27843136],
#         ...,
#         [ 0.05098045,  0.11372554, -0.20784312],
#         [ 0.02745104,  0.082353  , -0.23921567],
#         [ 0.07450986,  0.10588241, -0.21568626]],
#
#        [[ 0.25490201, -0.08235294, -0.25490195],
#         [ 0.27058828, -0.05882353, -0.2235294 ],
#         [ 0.12156868, -0.10588235, -0.21568626],
#         ...,
#         [ 0.05098045,  0.09803927, -0.23921567],
#         [ 0.02745104,  0.07450986, -0.25490195],
#         [ 0.09803927,  0.12941182, -0.19215685]]])

# %% [markdown]
# ### Print the shape of X_train and mask array

# %%
# Shape of x_train
X_train.shape
# Out:
# (409, 224, 224, 3)

# %%
# Shape of masks
masks.shape
# Out:
# (409, 224, 224)

# %% [markdown]
# ### Print a sample image and image array

# %%
from matplotlib import pyplot
print(X_train[n])
plt.imshow(X_train[n])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[ 0.41176474 -0.08235294 -0.49803919]
#   [ 0.41176474 -0.0745098  -0.51372552]
#   [ 0.4039216  -0.08235294 -0.52156866]
#   ...
#   [ 0.38823533 -0.19215685 -0.60784316]
#   [ 0.36470592 -0.20784312 -0.62352943]
#   [ 0.36470592 -0.19999999 -0.6156863 ]]
#
#  [[ 0.42745101 -0.06666666 -0.49803919]
#   [ 0.41960788 -0.06666666 -0.51372552]
#   [ 0.4039216  -0.08235294 -0.52156866]
#   ...
#   [ 0.38823533 -0.18431371 -0.6156863 ]
#   [ 0.38039219 -0.18431371 -0.62352943]
#   [ 0.38039219 -0.19215685 -0.6156863 ]]
#
#  [[ 0.42745101 -0.06666666 -0.50588238]
#   [ 0.42745101 -0.06666666 -0.50588238]
#   [ 0.43529415 -0.05882353 -0.50588238]
#   ...
#   [ 0.41176474 -0.14509803 -0.59215689]
#   [ 0.4039216  -0.16862744 -0.60784316]
#   [ 0.4039216  -0.16862744 -0.60000002]]
#
#  ...
#
#  [[ 0.30196083  0.03529418 -0.12156862]
#   [ 0.27058828 -0.02745098 -0.18431371]
#   [-0.01176471 -0.23137254 -0.35686272]
#   ...
#   [ 0.06666672  0.11372554 -0.19215685]
#   [ 0.05882359  0.10588241 -0.21568626]
#   [ 0.082353    0.11372554 -0.20784312]]
#
#  [[ 0.30196083 -0.01960784 -0.19999999]
#   [ 0.27058828 -0.04313725 -0.19999999]
#   [ 0.05882359 -0.16862744 -0.27843136]
#   ...
#   [ 0.05098045  0.11372554 -0.20784312]
#   [ 0.02745104  0.082353   -0.23921567]
#   [ 0.07450986  0.10588241 -0.21568626]]
#
#  [[ 0.25490201 -0.08235294 -0.25490195]
#   [ 0.27058828 -0.05882353 -0.2235294 ]
#   [ 0.12156868 -0.10588235 -0.21568626]
#   ...
#   [ 0.05098045  0.09803927 -0.23921567]
#   [ 0.02745104  0.07450986 -0.25490195]
#   [ 0.09803927  0.12941182 -0.19215685]]]

# %%
plt.imshow(masks[n])
plt.show()

# %% [markdown]
# ## Create the model
# - Add MobileNet as model with below parameter values
#   - input_shape: IMAGE_HEIGHT, IMAGE_WIDTH, 3
#   - include_top: False
#   - alpha: 1.0
#   - weights: "imagenet"
# - Add UNET architecture layers
#   - This is the trickiest part of the project, you need to research and implement it correctly

# %%
ALPHA = 1 # Width hyper parameter for MobileNet (0.25, 0.5, 0.75, 1.0). Higher width means more accurate but slower

HEIGHT_CELLS = 224
WIDTH_CELLS = 224

CELL_WIDTH = IMAGE_WIDTH / WIDTH_CELLS
CELL_HEIGHT = IMAGE_HEIGHT / HEIGHT_CELLS

EPOCHS = 80
BATCH_SIZE = 1
PATIENCE = 10

THREADS = 1

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import Concatenate, UpSampling2D, Conv2D, Reshape
from tensorflow.keras.models import Model


def create_model(trainable=True):
    model = MobileNet(input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3), include_top=False, alpha=ALPHA, weights="imagenet")

    for layer in model.layers:
        layer.trainable = trainable

    block1 = model.get_layer("conv_pw_5_relu").output
    block2 = model.get_layer("conv_pw_11_relu").output
    block3 = model.get_layer("conv_pw_13_relu").output

    x = Concatenate()([UpSampling2D()(block3), block2])
    x = Concatenate()([UpSampling2D()(x), block1])

    x = Conv2D(64, kernel_size=1, activation="sigmoid")(x)
    x = Reshape((HEIGHT_CELLS, WIDTH_CELLS))(x)

    return Model(inputs=model.input, outputs=x)

# %% [markdown]
# ### Call the create_model function

# %%
# Give trainable=False as argument, if you want to freeze lower layers for fast training (but low accuracy)
model = create_model()

# Print summary
model.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 32) 864         conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 112, 112, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)     (None, 112, 112, 32) 288         conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_bn (BatchNormalizatio (None, 112, 112, 32) 128         conv_dw_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu (ReLU)           (None, 112, 112, 32) 0           conv_dw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_1 (Conv2D)              (None, 112, 112, 64) 2048        conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_bn (BatchNormalizatio (None, 112, 112, 64) 256         conv_pw_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_relu (ReLU)           (None, 112, 112, 64) 0           conv_pw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_2 (ZeroPadding2D)      (None, 113, 113, 64) 0           conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)     (None, 56, 56, 64)   576         conv_pad_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_bn (BatchNormalizatio (None, 56, 56, 64)   256         conv_dw_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu (ReLU)           (None, 56, 56, 64)   0           conv_dw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_2 (Conv2D)              (None, 56, 56, 128)  8192        conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_2[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)     (None, 56, 56, 128)  1152        conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_dw_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_dw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_3 (Conv2D)              (None, 56, 56, 128)  16384       conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_3[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_4 (ZeroPadding2D)      (None, 57, 57, 128)  0           conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)     (None, 28, 28, 128)  1152        conv_pad_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv_dw_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu (ReLU)           (None, 28, 28, 128)  0           conv_dw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_4 (Conv2D)              (None, 28, 28, 256)  32768       conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_4[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)     (None, 28, 28, 256)  2304        conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_dw_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_dw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_5 (Conv2D)              (None, 28, 28, 256)  65536       conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_5[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_6 (ZeroPadding2D)      (None, 29, 29, 256)  0           conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)     (None, 14, 14, 256)  2304        conv_pad_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv_dw_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_relu (ReLU)           (None, 14, 14, 256)  0           conv_dw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_6 (Conv2D)              (None, 14, 14, 512)  131072      conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_6[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_7 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_7[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_8 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_8[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_9 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_9[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_10 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_10 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_10[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_11 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_11 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_11[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_12 (ZeroPadding2D)     (None, 15, 15, 512)  0           conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_12 (DepthwiseConv2D)    (None, 7, 7, 512)    4608        conv_pad_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_bn (BatchNormalizati (None, 7, 7, 512)    2048        conv_dw_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu (ReLU)          (None, 7, 7, 512)    0           conv_dw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_12 (Conv2D)             (None, 7, 7, 1024)   524288      conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_12[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_13 (DepthwiseConv2D)    (None, 7, 7, 1024)   9216        conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_dw_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_dw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_13 (Conv2D)             (None, 7, 7, 1024)   1048576     conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_13[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_13_bn[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 14, 14, 1024) 0           conv_pw_13_relu[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 14, 1536) 0           up_sampling2d[0][0]
#                                                                  conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 28, 28, 1536) 0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 1792) 0           up_sampling2d_1[0][0]
#                                                                  conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 64)   114752      concatenate_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 224, 224)     0           conv2d[0][0]
# ==================================================================================================
# Total params: 3,343,616
# Trainable params: 3,321,728
# Non-trainable params: 21,888
# __________________________________________________________________________________________________

# %% [markdown]
# ### Define dice coefficient function
# - Create a function to calculate dice coefficient

# %%
import tensorflow
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.backend import log, epsilon

# %%
def dice_coefficient(y_true, y_pred):
    numerator = 2 * tensorflow.reduce_sum(y_true * y_pred)
    denominator = tensorflow.reduce_sum(y_true + y_pred)

    return numerator / (denominator + epsilon())

# %% [markdown]
# ### Define loss

# %%
def loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - log(dice_coefficient(y_true, y_pred) + epsilon())

# %% [markdown]
# ### Compile the model
# - Complie the model using below parameters
#   - loss: use the loss function defined above
#   - optimizers: use Adam optimizer
#   - metrics: use dice_coefficient function defined above

# %%
optimizer = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss=loss, optimizer=optimizer, metrics=[dice_coefficient])

# %% [markdown]
# ### Define checkpoint and earlystopping

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint("model-{loss:.2f}.h5", monitor="loss", verbose=1, save_best_only=True, save_weights_only=True, mode="min", save_freq='epoch')
stop = EarlyStopping(monitor="loss", patience=5, mode="min")
reduce_lr = ReduceLROnPlateau(monitor="loss", factor=0.2, patience=5, min_lr=1e-6, verbose=1, mode="min")

# %% [markdown]
# ### Fit the model
# - Fit the model using below parameters
#   - epochs: you can decide
#   - batch_size: 1
#   - callbacks: checkpoint, reduce_lr, stop

# %%
model.fit(x=X_train,y=masks, epochs=EPOCHS, batch_size=1, validation_data=None, callbacks=[checkpoint, reduce_lr, stop], shuffle=True,workers=1, use_multiprocessing=False, verbose=1)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 409 samples
# Epoch 1/80
# 407/409 [============================>.] - ETA: 0s - loss: 2.1202 - dice_coefficient: 0.2449
# Epoch 00001: loss improved from inf to 2.12149, saving model to model-2.12.h5
# 409/409 [==============================] - 28s 68ms/sample - loss: 2.1215 - dice_coefficient: 0.2443
# Epoch 2/80
# 408/409 [============================>.] - ETA: 0s - loss: 1.7914 - dice_coefficient: 0.2933
# Epoch 00002: loss improved from 2.12149 to 1.79082, saving model to model-1.79.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 1.7908 - dice_coefficient: 0.2932
# Epoch 3/80
# 407/409 [============================>.] - ETA: 0s - loss: 1.6087 - dice_coefficient: 0.3289
# Epoch 00003: loss improved from 1.79082 to 1.60807, saving model to model-1.61.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 1.6081 - dice_coefficient: 0.3287
# Epoch 4/80
# 407/409 [============================>.] - ETA: 0s - loss: 1.4460 - dice_coefficient: 0.3639
# Epoch 00004: loss improved from 1.60807 to 1.44736, saving model to model-1.45.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 1.4474 - dice_coefficient: 0.3635
# Epoch 5/80
# 407/409 [============================>.] - ETA: 0s - loss: 1.3301 - dice_coefficient: 0.3940
# Epoch 00005: loss improved from 1.44736 to 1.32960, saving model to model-1.33.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 1.3296 - dice_coefficient: 0.3939
# Epoch 6/80
# 407/409 [============================>.] - ETA: 0s - loss: 1.2371 - dice_coefficient: 0.4220
# Epoch 00006: loss improved from 1.32960 to 1.23734, saving model to model-1.24.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 1.2373 - dice_coefficient: 0.4218
# Epoch 7/80
# 407/409 [============================>.] - ETA: 0s - loss: 1.1517 - dice_coefficient: 0.4499
# Epoch 00007: loss improved from 1.23734 to 1.15154, saving model to model-1.15.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 1.1515 - dice_coefficient: 0.4505
# Epoch 8/80
# 407/409 [============================>.] - ETA: 0s - loss: 1.0824 - dice_coefficient: 0.4766
# Epoch 00008: loss improved from 1.15154 to 1.08240, saving model to model-1.08.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 1.0824 - dice_coefficient: 0.4762
# Epoch 9/80
# 407/409 [============================>.] - ETA: 0s - loss: 1.0257 - dice_coefficient: 0.4985
# Epoch 00009: loss improved from 1.08240 to 1.02545, saving model to model-1.03.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 1.0254 - dice_coefficient: 0.4983
# Epoch 10/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.9783 - dice_coefficient: 0.5175
# Epoch 00010: loss improved from 1.02545 to 0.97812, saving model to model-0.98.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.9781 - dice_coefficient: 0.5177
# Epoch 11/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.9407 - dice_coefficient: 0.5329
# Epoch 00011: loss improved from 0.97812 to 0.94056, saving model to model-0.94.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.9406 - dice_coefficient: 0.5327
# Epoch 12/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.9076 - dice_coefficient: 0.5469
# Epoch 00012: loss improved from 0.94056 to 0.90833, saving model to model-0.91.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.9083 - dice_coefficient: 0.5462
# Epoch 13/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.8818 - dice_coefficient: 0.5570
# Epoch 00013: loss improved from 0.90833 to 0.88261, saving model to model-0.88.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.8826 - dice_coefficient: 0.5566
# Epoch 14/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.8637 - dice_coefficient: 0.5652
# Epoch 00014: loss improved from 0.88261 to 0.86358, saving model to model-0.86.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.8636 - dice_coefficient: 0.5651
# Epoch 15/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.8442 - dice_coefficient: 0.5731
# Epoch 00015: loss improved from 0.86358 to 0.84450, saving model to model-0.84.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.8445 - dice_coefficient: 0.5729
# Epoch 16/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.8280 - dice_coefficient: 0.5800
# Epoch 00016: loss improved from 0.84450 to 0.82811, saving model to model-0.83.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.8281 - dice_coefficient: 0.5801
# Epoch 17/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.8138 - dice_coefficient: 0.5868
# Epoch 00017: loss improved from 0.82811 to 0.81320, saving model to model-0.81.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.8132 - dice_coefficient: 0.5867
# Epoch 18/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7976 - dice_coefficient: 0.5935
# Epoch 00018: loss improved from 0.81320 to 0.79736, saving model to model-0.80.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7974 - dice_coefficient: 0.5932
# Epoch 19/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.7863 - dice_coefficient: 0.5982
# Epoch 00019: loss improved from 0.79736 to 0.78575, saving model to model-0.79.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.7857 - dice_coefficient: 0.5983
# Epoch 20/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7776 - dice_coefficient: 0.6018
# Epoch 00020: loss improved from 0.78575 to 0.77799, saving model to model-0.78.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7780 - dice_coefficient: 0.6017
# Epoch 21/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7697 - dice_coefficient: 0.6058
# Epoch 00021: loss improved from 0.77799 to 0.76952, saving model to model-0.77.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7695 - dice_coefficient: 0.6058
# Epoch 22/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7603 - dice_coefficient: 0.6097
# Epoch 00022: loss improved from 0.76952 to 0.76034, saving model to model-0.76.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7603 - dice_coefficient: 0.6097
# Epoch 23/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7535 - dice_coefficient: 0.6128
# Epoch 00023: loss improved from 0.76034 to 0.75282, saving model to model-0.75.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7528 - dice_coefficient: 0.6128
# Epoch 24/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7464 - dice_coefficient: 0.6159
# Epoch 00024: loss improved from 0.75282 to 0.74628, saving model to model-0.75.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.7463 - dice_coefficient: 0.6161
# Epoch 25/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7405 - dice_coefficient: 0.6180
# Epoch 00025: loss improved from 0.74628 to 0.74122, saving model to model-0.74.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7412 - dice_coefficient: 0.6179
# Epoch 26/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7353 - dice_coefficient: 0.6210
# Epoch 00026: loss improved from 0.74122 to 0.73500, saving model to model-0.74.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.7350 - dice_coefficient: 0.6209
# Epoch 27/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7290 - dice_coefficient: 0.6240
# Epoch 00027: loss improved from 0.73500 to 0.72808, saving model to model-0.73.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7281 - dice_coefficient: 0.6241
# Epoch 28/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7218 - dice_coefficient: 0.6271
# Epoch 00028: loss improved from 0.72808 to 0.72155, saving model to model-0.72.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7216 - dice_coefficient: 0.6270
# Epoch 29/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7157 - dice_coefficient: 0.6294
# Epoch 00029: loss improved from 0.72155 to 0.71490, saving model to model-0.71.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7149 - dice_coefficient: 0.6297
# Epoch 30/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7111 - dice_coefficient: 0.6320
# Epoch 00030: loss improved from 0.71490 to 0.71032, saving model to model-0.71.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.7103 - dice_coefficient: 0.6321
# Epoch 31/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.7085 - dice_coefficient: 0.6327
# Epoch 00031: loss improved from 0.71032 to 0.70764, saving model to model-0.71.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.7076 - dice_coefficient: 0.6330
# Epoch 32/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.7039 - dice_coefficient: 0.6350
# Epoch 00032: loss improved from 0.70764 to 0.70374, saving model to model-0.70.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.7037 - dice_coefficient: 0.6350
# Epoch 33/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6977 - dice_coefficient: 0.6379
# Epoch 00033: loss improved from 0.70374 to 0.69702, saving model to model-0.70.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.6970 - dice_coefficient: 0.6380
# Epoch 34/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6905 - dice_coefficient: 0.6409
# Epoch 00034: loss improved from 0.69702 to 0.69029, saving model to model-0.69.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.6903 - dice_coefficient: 0.6409
# Epoch 35/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6866 - dice_coefficient: 0.6428
# Epoch 00035: loss improved from 0.69029 to 0.68620, saving model to model-0.69.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.6862 - dice_coefficient: 0.6427
# Epoch 36/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6801 - dice_coefficient: 0.6457
# Epoch 00036: loss improved from 0.68620 to 0.67944, saving model to model-0.68.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.6794 - dice_coefficient: 0.6461
# Epoch 37/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6741 - dice_coefficient: 0.6486
# Epoch 00037: loss improved from 0.67944 to 0.67406, saving model to model-0.67.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.6741 - dice_coefficient: 0.6485
# Epoch 38/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6700 - dice_coefficient: 0.6507
# Epoch 00038: loss improved from 0.67406 to 0.66987, saving model to model-0.67.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.6699 - dice_coefficient: 0.6506
# Epoch 39/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6646 - dice_coefficient: 0.6534
# Epoch 00039: loss improved from 0.66987 to 0.66464, saving model to model-0.66.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.6646 - dice_coefficient: 0.6531
# Epoch 40/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6589 - dice_coefficient: 0.6559
# Epoch 00040: loss improved from 0.66464 to 0.65832, saving model to model-0.66.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.6583 - dice_coefficient: 0.6560
# Epoch 41/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6541 - dice_coefficient: 0.6584
# Epoch 00041: loss improved from 0.65832 to 0.65345, saving model to model-0.65.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.6534 - dice_coefficient: 0.6586
# Epoch 42/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6461 - dice_coefficient: 0.6623
# Epoch 00042: loss improved from 0.65345 to 0.64553, saving model to model-0.65.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.6455 - dice_coefficient: 0.6622
# Epoch 43/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6392 - dice_coefficient: 0.6660
# Epoch 00043: loss improved from 0.64553 to 0.63901, saving model to model-0.64.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.6390 - dice_coefficient: 0.6659
# Epoch 44/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6338 - dice_coefficient: 0.6682
# Epoch 00044: loss improved from 0.63901 to 0.63351, saving model to model-0.63.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.6335 - dice_coefficient: 0.6681
# Epoch 45/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6259 - dice_coefficient: 0.6726
# Epoch 00045: loss improved from 0.63351 to 0.62502, saving model to model-0.63.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.6250 - dice_coefficient: 0.6726
# Epoch 46/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6210 - dice_coefficient: 0.6754
# Epoch 00046: loss improved from 0.62502 to 0.62069, saving model to model-0.62.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.6207 - dice_coefficient: 0.6752
# Epoch 47/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6129 - dice_coefficient: 0.6793
# Epoch 00047: loss improved from 0.62069 to 0.61282, saving model to model-0.61.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.6128 - dice_coefficient: 0.6790
# Epoch 48/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.6053 - dice_coefficient: 0.6830
# Epoch 00048: loss improved from 0.61282 to 0.60542, saving model to model-0.61.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.6054 - dice_coefficient: 0.6830
# Epoch 49/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.6001 - dice_coefficient: 0.6859
# Epoch 00049: loss improved from 0.60542 to 0.59967, saving model to model-0.60.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5997 - dice_coefficient: 0.6858
# Epoch 50/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.5936 - dice_coefficient: 0.6891
# Epoch 00050: loss improved from 0.59967 to 0.59317, saving model to model-0.59.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5932 - dice_coefficient: 0.6892
# Epoch 51/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5873 - dice_coefficient: 0.6931
# Epoch 00051: loss improved from 0.59317 to 0.58731, saving model to model-0.59.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.5873 - dice_coefficient: 0.6928
# Epoch 52/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5825 - dice_coefficient: 0.6955
# Epoch 00052: loss improved from 0.58731 to 0.58157, saving model to model-0.58.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5816 - dice_coefficient: 0.6956
# Epoch 53/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5747 - dice_coefficient: 0.6996
# Epoch 00053: loss improved from 0.58157 to 0.57445, saving model to model-0.57.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5744 - dice_coefficient: 0.6996
# Epoch 54/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5658 - dice_coefficient: 0.7043
# Epoch 00054: loss improved from 0.57445 to 0.56624, saving model to model-0.57.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.5662 - dice_coefficient: 0.7041
# Epoch 55/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5618 - dice_coefficient: 0.7066
# Epoch 00055: loss improved from 0.56624 to 0.56089, saving model to model-0.56.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5609 - dice_coefficient: 0.7067
# Epoch 56/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5542 - dice_coefficient: 0.7106
# Epoch 00056: loss improved from 0.56089 to 0.55520, saving model to model-0.56.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.5552 - dice_coefficient: 0.7105
# Epoch 57/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5515 - dice_coefficient: 0.7125
# Epoch 00057: loss improved from 0.55520 to 0.55041, saving model to model-0.55.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5504 - dice_coefficient: 0.7128
# Epoch 58/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5438 - dice_coefficient: 0.7167
# Epoch 00058: loss improved from 0.55041 to 0.54420, saving model to model-0.54.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5442 - dice_coefficient: 0.7165
# Epoch 59/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.5378 - dice_coefficient: 0.7199
# Epoch 00059: loss improved from 0.54420 to 0.53770, saving model to model-0.54.h5
# 409/409 [==============================] - 15s 38ms/sample - loss: 0.5377 - dice_coefficient: 0.7199
# Epoch 60/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5315 - dice_coefficient: 0.7236
# Epoch 00060: loss improved from 0.53770 to 0.53102, saving model to model-0.53.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5310 - dice_coefficient: 0.7236
# Epoch 61/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5262 - dice_coefficient: 0.7261
# Epoch 00061: loss improved from 0.53102 to 0.52649, saving model to model-0.53.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.5265 - dice_coefficient: 0.7261
# Epoch 62/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5227 - dice_coefficient: 0.7285
# Epoch 00062: loss improved from 0.52649 to 0.52245, saving model to model-0.52.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5224 - dice_coefficient: 0.7285
# Epoch 63/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5155 - dice_coefficient: 0.7325
# Epoch 00063: loss improved from 0.52245 to 0.51478, saving model to model-0.51.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5148 - dice_coefficient: 0.7327
# Epoch 64/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5094 - dice_coefficient: 0.7360
# Epoch 00064: loss improved from 0.51478 to 0.50874, saving model to model-0.51.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.5087 - dice_coefficient: 0.7360
# Epoch 65/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.5032 - dice_coefficient: 0.7391
# Epoch 00065: loss improved from 0.50874 to 0.50326, saving model to model-0.50.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.5033 - dice_coefficient: 0.7390
# Epoch 66/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.4992 - dice_coefficient: 0.7417
# Epoch 00066: loss improved from 0.50326 to 0.49906, saving model to model-0.50.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4991 - dice_coefficient: 0.7418
# Epoch 67/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.4955 - dice_coefficient: 0.7435
# Epoch 00067: loss improved from 0.49906 to 0.49554, saving model to model-0.50.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4955 - dice_coefficient: 0.7438
# Epoch 68/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4928 - dice_coefficient: 0.7452
# Epoch 00068: loss improved from 0.49554 to 0.49284, saving model to model-0.49.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.4928 - dice_coefficient: 0.7453
# Epoch 69/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4868 - dice_coefficient: 0.7487
# Epoch 00069: loss improved from 0.49284 to 0.48631, saving model to model-0.49.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4863 - dice_coefficient: 0.7488
# Epoch 70/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4764 - dice_coefficient: 0.7546
# Epoch 00070: loss improved from 0.48631 to 0.47658, saving model to model-0.48.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.4766 - dice_coefficient: 0.7544
# Epoch 71/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4716 - dice_coefficient: 0.7568
# Epoch 00071: loss improved from 0.47658 to 0.47116, saving model to model-0.47.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.4712 - dice_coefficient: 0.7570
# Epoch 72/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4681 - dice_coefficient: 0.7594
# Epoch 00072: loss improved from 0.47116 to 0.46731, saving model to model-0.47.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4673 - dice_coefficient: 0.7595
# Epoch 73/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4644 - dice_coefficient: 0.7615
# Epoch 00073: loss improved from 0.46731 to 0.46480, saving model to model-0.46.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.4648 - dice_coefficient: 0.7614
# Epoch 74/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.4608 - dice_coefficient: 0.7635
# Epoch 00074: loss improved from 0.46480 to 0.46082, saving model to model-0.46.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4608 - dice_coefficient: 0.7634
# Epoch 75/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4575 - dice_coefficient: 0.7659
# Epoch 00075: loss improved from 0.46082 to 0.45663, saving model to model-0.46.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4566 - dice_coefficient: 0.7662
# Epoch 76/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4513 - dice_coefficient: 0.7695
# Epoch 00076: loss improved from 0.45663 to 0.45118, saving model to model-0.45.h5
# 409/409 [==============================] - 15s 36ms/sample - loss: 0.4512 - dice_coefficient: 0.7692
# Epoch 77/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4470 - dice_coefficient: 0.7718
# Epoch 00077: loss improved from 0.45118 to 0.44610, saving model to model-0.45.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4461 - dice_coefficient: 0.7722
# Epoch 78/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4413 - dice_coefficient: 0.7742
# Epoch 00078: loss improved from 0.44610 to 0.44192, saving model to model-0.44.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4419 - dice_coefficient: 0.7742
# Epoch 79/80
# 407/409 [============================>.] - ETA: 0s - loss: 0.4373 - dice_coefficient: 0.7769
# Epoch 00079: loss improved from 0.44192 to 0.43689, saving model to model-0.44.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4369 - dice_coefficient: 0.7770
# Epoch 80/80
# 408/409 [============================>.] - ETA: 0s - loss: 0.4313 - dice_coefficient: 0.7802
# Epoch 00080: loss improved from 0.43689 to 0.43135, saving model to model-0.43.h5
# 409/409 [==============================] - 15s 37ms/sample - loss: 0.4314 - dice_coefficient: 0.7801

# %% [markdown]
# ### Get the predicted mask for a sample image

# %%
from google.colab.patches import cv2_imshow

# %%
WEIGHTS_FILE = "model-0.43.h5"
model1 = create_model()
model1.load_weights(WEIGHTS_FILE)
preds_train = model1.predict(X_train, verbose=1)
# Out:
# 409/409 [==============================] - 3s 8ms/sample

# %%
img_no = n
plt.imshow(X_train[img_no])
plt.savefig(str(img_no) + '-image.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(preds_train[img_no])
plt.savefig(str(img_no) + '-mask.png')

# %% [markdown]
# ### Impose the mask on the image

# %%
THRESHOLD = 0.1
sample_image = X_train[n]
image = cv2.resize(sample_image, (IMAGE_WIDTH, IMAGE_HEIGHT))
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

pred_mask = cv2.resize(1.0*(model.predict(x=np.array([feat_scaled]))[0] > THRESHOLD), (IMAGE_WIDTH,IMAGE_HEIGHT))

image2 = image
image2[:,:,0] = pred_mask*image[:,:,0]
image2[:,:,1] = pred_mask*image[:,:,1]
image2[:,:,2] = pred_mask*image[:,:,2]

out_image = image2
plt.imshow(out_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from google.colab.patches import cv2_imshow
import cv2
image_name = str(img_no) + '-image.png'
mask_name = str(img_no) + '-mask.png'
img = cv2.imread(image_name, 1)
mask = cv2.imread(mask_name, 1)
impose_mask = cv2.add(img,mask)
cv2_imshow(impose_mask)
# Out:
# <PIL.Image.Image image mode=RGB size=432x288 at 0x7F8A53C957B8>
